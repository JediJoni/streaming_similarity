# %%
import sys
from pathlib import Path

# Find the repo root by walking up until we see "src/"
PROJECT_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "src").exists())

# Put repo root at the front of sys.path so `import src...` works
sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT =", PROJECT_ROOT)
# Out:
# PROJECT_ROOT = /Users/jonaskorganas/coding_projects/streaming_similarity

# %%
import pandas as pd
from src.data.build_catalog import load_raw_csvs, build_catalog, save_catalog_parquet

# %%
RAW_DIR = PROJECT_ROOT / "data" / "raw"
OUT_PATH = PROJECT_ROOT / "data" / "processed" / "catalog.parquet"

platform_dfs = load_raw_csvs(RAW_DIR)
catalog = build_catalog(platform_dfs)
catalog.shape, catalog.columns
# Out:
# ((19925, 16),
#  Index(['title_id', 'platform', 'title', 'type', 'release_year',
#         'duration_mins', 'duration_seasons', 'listed_in', 'country', 'cast',
#         'genres', 'countries', 'cast_list', 'n_genres', 'n_countries',
#         'n_cast'],
#        dtype='object'))

# %%
catalog.head(3)
# Out:
#        title_id      platform                 title   type  release_year  \
# 0  6070fa3e698b  Amazon Prime   The Grand Seduction  Movie          2014
# 1  edf4387268f5  Amazon Prime  Take Care Good Night  Movie          2018
# 2  7f037bef961f  Amazon Prime  Secrets of Deception  Movie          2017
#
#    duration_mins  duration_seasons                listed_in        country  \
# 0          113.0               NaN            Comedy, Drama         Canada
# 1          110.0               NaN     Drama, International          India
# 2           74.0               NaN  Action, Drama, Suspense  United States
#
#                                                 cast  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...
#
#                       genres        countries  \
# 0            [Comedy, Drama]         [Canada]
# 1     [Drama, International]          [India]
# 2  [Action, Drama, Suspense]  [United States]
#
#                                            cast_list  n_genres  n_countries  \
# 0   [Brendan Gleeson, Taylor Kitsch, Gordon Pinsent]         2            1
# 1  [Mahesh Manjrekar, Abhay Mahajan, Sachin Khede...         2            1
# 2  [Tom Sizemore, Lorenzo Lamas, Robert LaSardo, ...         3            1
#
#    n_cast
# 0       3
# 1       3
# 2       6

# %%
# sanity checks
assert catalog["title_id"].isna().sum() == 0
assert set(catalog["platform"].unique()) == {"Netflix", "Amazon Prime", "Disney+"}

# %%
save_catalog_parquet(catalog, OUT_PATH)
OUT_PATH
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 save_catalog_parquet(catalog, OUT_PATH)
#       2 OUT_PATH
#
# File ~/coding_projects/streaming_similarity/src/data/build_catalog.py:145, in save_catalog_parquet(catalog, out_path)
#     143 out_path = Path(out_path)
#     144 out_path.parent.mkdir(parents=True, exist_ok=True)
# --> 145 catalog.to_parquet(out_path, index=False)
#
# File ~/coding_projects/streaming_similarity/.venv/lib/python3.14/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/coding_projects/streaming_similarity/.venv/lib/python3.14/site-packages/pandas/core/frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File ~/coding_projects/streaming_similarity/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:478, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 if isinstance(partition_cols, str):
#     477     partition_cols = [partition_cols]
# --> 478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     482 impl.write(
#     483     df,
#     484     path_or_buf,
#    (...)    490     **kwargs,
#     491 )
#
# File ~/coding_projects/streaming_similarity/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.
